# %%
import pandas as pd
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15212\2035458946.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('OneDrive/honey.csv')

# %%
df.head()
# Out:
#    radius(in m)  c1 Deflection(in m)(cantilever)  \
# 0             0                         0.031411
# 1             1                         0.033245
# 2             2                         0.032834
#
#    c2Deflection(in m)(Static Indeterminacy)  c3Deflection(in m)(UVL)  \
# 0                                  0.001555                   9.8979
# 1                                  0.001640                   9.4380
# 2                                  0.001350                   9.1600
#
#    c4Deflection(in m)(UDL)  C1 Stress(in Pa)(cantilever)  \
# 0                   1.3794                        8.7786
# 1                   1.3005                        8.7096
# 2                   1.2630                        8.6190
#
#    C2Stress(in Pa)(Static Indeterminacy)  C3Stress(in Pa)(UVL)  \
# 0                                0.84583                1552.2
# 1                                1.02249                1690.2
# ...

# %%
sns.lineplot('radius(in m)', 'c1 Deflection(in m)(cantilever)', ci=None, data=df)

# %%
sns.lineplot('radius(in m)', 'c2Deflection(in m)(Static Indeterminacy)', ci=None, data=df)

# %%
sns.lineplot('radius(in m)', 'c3Deflection(in m)(UVL)', ci=None, data=df)

# %%
sns.lineplot('radius(in m)', 'c4Deflection(in m)(UDL)', ci=None, data=df)

# %%
sns.lineplot('radius(in m)', 'c1 Deflection(in m)(cantilever)', ci=None, data=df, label = "CLB")
sns.lineplot('radius(in m)', 'c2Deflection(in m)(Static Indeterminacy)', ci=None, data=df)
sns.lineplot('radius(in m)', 'c3Deflection(in m)(UVL)', ci=None, data=df)
sns.lineplot('radius(in m)', 'c4Deflection(in m)(UDL)', ci=None, data=df)

# %%
sns.lineplot('radius(in m)', 'C1 Stress(in Pa)(cantilever)', ci=None, data=df)

# %%
sns.lineplot('radius(in m)', 'C2Stress(in Pa)(Static Indeterminacy)', ci=None, data=df)

# %%
sns.lineplot('radius(in m)', 'C3Stress(in Pa)(UVL)', ci=None, data=df)

# %%
sns.lineplot('radius(in m)', 'C4Stress(in Pa)(UDL)', ci=None, data=df)

# %%
sns.lineplot('radius(in m)', 'Mass(in kg)', ci=None, data=df)

# %%
sns.lineplot('radius(in m)', 'C1 Stress(in Pa)(cantilever)', ci=None, data=df, label = "CLB")
sns.lineplot('radius(in m)', 'C2Stress(in Pa)(Static Indeterminacy)', ci=None, data=df, label = "SID")
sns.lineplot('radius(in m)', 'C3Stress(in Pa)(UVL)', ci=None, data=df, label = "UVL")
sns.lineplot('radius(in m)', 'C4Stress(in Pa)(UDL)', ci=None, data=df, label = "UDL")

# %%
sns.lineplot('radius(in m)', 'c1 Deflection(in m)(cantilever)', ci=None, data=df, label = "CLB")
sns.lineplot('radius(in m)', 'c2Deflection(in m)(Static Indeterminacy)', ci=None, data=df, label = "SID")
sns.lineplot('radius(in m)', 'c3Deflection(in m)(UVL)', ci=None, data=df, label = "UVL")
sns.lineplot('radius(in m)', 'c4Deflection(in m)(UDL)', ci=None, data=df, label = "UDL")

# %%
dfT = pd.read_csv('C:/Users/shivam kumar jaiswal/OneDrive/hc0r.csv')
dfT.head()
sns.lineplot('Time [s]', 'Average Temperature (0.00m) [¡C]', ci=None, data=dfT,label = "R=O.OO0M")
sns.lineplot('Time [s]', 'Average  Temperature (0.001m)[C]', ci=None, data=dfT,label = "R=O.OO1M")
sns.lineplot('Time [s]', 'Average temperatur (0.002m)[C]', ci=None, data=dfT,label = "R=O.OO2M")
